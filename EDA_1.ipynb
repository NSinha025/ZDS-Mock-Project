# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel("Sample Dataset (1).xlsx")

# %%
dataset
# Out:
#        OrderNumber Sales Channel WarehouseCode ProcuredDate  OrderDate  \
# 0      SO - 000101      In-Store  WARE-UHY1004   2017-12-31 2018-05-31
# 1      SO - 000102        Online  WARE-NMK1003   2017-12-31 2018-05-31
# 2      SO - 000103   Distributor  WARE-UHY1004   2017-12-31 2018-05-31
# 3      SO - 000104     Wholesale  WARE-NMK1003   2017-12-31 2018-05-31
# 4      SO - 000105   Distributor  WARE-NMK1003   2018-04-10 2018-05-31
# ...            ...           ...           ...          ...        ...
# 7477  SO - 0007581   Distributor  WARE-UHY1004   2020-06-18 2020-10-31
# 7478  SO - 0007582      In-Store  WARE-UHY1004   2020-06-18 2020-10-31
# 7479  SO - 0007583      In-Store  WARE-XYS1001   2020-06-18 2020-10-31
# 7480  SO - 0007584      In-Store  WARE-NMK1003   2020-06-18 2020-10-31
# 7481  SO - 0007585      In-Store  WARE-NMK1003   2020-06-18 2020-10-31
#
#        ShipDate DeliveryDate CurrencyCode  SalesTeam Code  Customer Code  \
# ...

# %%
dataset[dataset["ProcuredDate"]>dataset["OrderDate"]]
# Out:
# Empty DataFrame
# Columns: [OrderNumber, Sales Channel, WarehouseCode, ProcuredDate, OrderDate, ShipDate, DeliveryDate, CurrencyCode, SalesTeam Code, Customer Code, Store Code, Product Code, Order Quantity, Discount Applied, Unit Price, Unit Cost]
# Index: []

# %% [markdown]
# This means that the demand and supply kind of needs are fullfilled and no order is placed before the item is procured in warehouses of the company/retail store.

# %%
from datetime import timedelta
delay_df = pd.DataFrame(dataset["DeliveryDate"]-dataset["OrderDate"])
delay_df[delay_df[0]>timedelta(days=10)]
# type(delay_df[0][0])
# Out:
#            0
# 0    19 days
# 1    32 days
# 2    31 days
# 4    26 days
# 5    13 days
# ...      ...
# 7475 19 days
# 7477 14 days
# 7479 16 days
# 7480 11 days
# 7481 28 days
#
# [6501 rows x 1 columns]

# %%
ans = (981/7482)*100
ans
# Out:
# 13.111467522052928
